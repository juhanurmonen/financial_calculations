# %% [markdown]
# # Rahoituslaskennan menetelmiä

# %% [markdown]
# ## Tehtävä 6: Korkosijoitusten hinnoittelu ja riskiluvut

# %% [markdown]
# ### Oppimistavoitteet

# %% [markdown]
# Tässä tehtävässä tutustutaan edelleen korkosijoitusten hintojen ja riskilukujen laskemiseen.

# %% [markdown]
# Tee Excel-tiedostosta helppolukuinen ja hyvien tapojen mukainen. Kirjoita lisäksi jokaiseen osaan asianmukaiset ohjeet käyttäjille, jotka haluavat soveltaa tekemääsi laskentapohjaa. Lisää samaan tiedostoon (esim. luontevasti laskentapohjasi viereen) lyhyet ja ytimekkäät ohjeet jatkokehittäjille, jotka ehkä haluavat kehittää ja parantaa laskentapohjaasi.

# %% [markdown]
# Tee kukin osa omaan välilehteensä.

# %% [markdown]
# ### Tausta

# %% [markdown]
# Olet sijoitusneuvojana pienasiakasyrityksessä. Asiakkaasi — tervejärkinen ja aktiivinen pariskunta, jolta on kuitenkin niin tilaston kuin myös rahoituksen perusteet jääneet aikoinaan käymättä — haluaa sinun selvittävän rahoitusmarkkinoita. Ohessa siihen liittyvä (kts. Excel-tiedosto) avulla.

# %% [markdown]
# ### Nollakuponkilainan hinta

# %% [markdown]
# Tee siis ensinnäkin tarvittavat laskelmat laskemiseen. Tee ne hyvien tapojen mukaisesti niin, että laskelmat ovat omalla välilehdellään ja tunnusluvut omallaan.

# %% [markdown]
# __Lainojen tiedot__:
# Tarkastelu- ja hankintapäivät 30.9.2016.<br />
# Kuponkilaina: Suomen valtion jvk 30.9.2021 2,18 %. Nimellisarvo 1 960 000, vuosittainen kuponki.<br />
# Nollakuponkilaina: Sijoitustodistus 30.9.2020 0 %, nimellisarvo 730 000.<br />
# Korkotaso 0,672 %.

# %% [markdown]
# Toisin sanoen:
#
# Nollakuponkilaina (korko vakio):
# * Täytä nollakuponkilainan kassavirrat ja korot sekä laske kassavirtojen nykyarvot.
# * Selitä, mitä nuo lasketut nykyarvot tarkoittavat.
# * Laske seuraavat tunnusluvut: vakio- ja muuttuva diskonttokorko euroina (nykyarvot) sekä prosentteina (lainan hinta).
#
# Kuponkilaina (korko vakio):
# * Täytä kuponkilainan kassavirrat (viittauksina; huom. viimeinen vuosi) ja diskonttokorot sekä laske kassavirtojen nykyarvot.
# * Selitä, mitä nuo lasketut nykyarvot tarkoittavat.
# * Laske seuraavat tunnusluvut: vakio- ja muuttuva diskonttokorko euroina (nykyarvot) sekä prosentteina (lainan hinta).
# * Piirrä pylväsdiagrammi kassavirroista.
#
# Korkokäyrä: hyödynnetään korkokäyrää hinnoittelussa:
# * Piirrä korkokäyrä-välilehdeltä löytyvistä diskonttokoroista viivakuvio niin, että vaaka-akselilla on maturiteetti vuosina;
# * Kommentoi asiakkaallesi korkokäyrää ja sen käytännön merkitystä asiayhteydessään ja miten se vaikuttaa lainan nykyarvoon.
# * Arvioi käyrästä kesäkuun 2019 korkotaso.

# %% [markdown]
# ### Korkokäyrä

# %% [markdown]
# Pyritään korkokäyrän avulla arvioimaan lainan realistisempi hinta.
#
# Korkokäyrä ja nollakuponkilainan hinnoittelu:
# * Korvaa nollakuponkilainan diskonttokorot muuttuvilla koroilla.
# * Laske lainan uusi nykyarvo ja lainan hinta Tunnusluvut-välilehdelle.
# * Kommentoi, miten vakiokorolla ja muuttuvalla korolla lasketut tunnusluvut eroavat toisistaan ja selitä eroa.
# * Kommentoi korkotason muutoksen ja lainan hinnan välistä yhteyttä.
#
# Korkokäyrä ja kuponkilainan hinnoittelu:
# * Korvaa kuponkilainan diskonttokorot muuttuvilla koroilla.
# * Laske lainan uusi nykyarvo ja lainan hinta Tunnusluvut-välilehdelle.
# * Kommentoi, miten vakiokorolla ja muuttuvalla korolla lasketut tunnusluvut eroavat toisistaan ja selitä eroa.
#
# Vertaa nollakupunkilainaa ja kupunkilainaa
# * Kommentoi, kumman lainan hinta muuttui enemmän selitä ero.
# * Kommentoi, kumpi laina kannattaa valita, jos nimenomainen tehtävä on minimoida korkoriski (perustele).
#
# Puolivuosikuponkilainan nykyarvo:
# * Täytä annettuina päivinä puolivuosittaiset kassavirrat ja muuttuvat diskonttokorot sekä lopuksi nykyarvot.
# * Laske lopuksi tunnusluvut lainan nykyarvo ja lainan hinta sekä piirrä pylväskuvio kassavirroista.

# %% [markdown]
# ### Kertynyt korko

# %% [markdown]
# Kertynyt korko: laske kuponkilainan kertynyt korko, clean arvo ja markkinahinta.
# * Määritä siis kertyneet päivät edellisestä kuponkipäivästä prosentteina vuodesta, kertynyt korko sekä clean arvo ja markkinahinta.
# * Selvitä asiakkaalle, ovatko aiemmin lasketut markkinahinnat olleet clean vai dirty hintoja ja miksi näin.

# %% [markdown]
# ### Sisäinen korkokanta

# %% [markdown]
# Määritetään korkosijoitusten sisäinen korkokanta erilaisin menetelmin.
# * Määritä kuponkilainan ja nollakuponkilainan yied to maturity IRR-funktiolla ja siirrä nuo tunnusluvut niille tarkoitetulle välilehdelle.
# * Selvitä, mitä laskemasi luvut tarkoittavat.
#
# * Määritä kuponkilainan yied to maturity YIELD-funktiolla ja siirrä nuo tunnusluvut omalle välilehdelleen.
# * Onnistuuko nollakuponkilainan YTM:n laskeminen tällä funktiolla?
#
# * Selvitä, miten eri tavoin lasketut korkokannat eroavat.

# %% [markdown]
# ### Luottoluokitusjakaumat

# %% [markdown]
# Laske korkosalkun luottoluokitusjakauma.
# * Laske kunkin luottoluokan markkina-arvo summa (sumif-funktiolla) sekä prosenttiosuus.
# * Tee samat toimenpiteet myös karkeammalle luottojakaumalle (sumif-funktio ei nyt sovellu ainakaan suoraan).
# * Tee kummastakin jakaumasta piirakkakuvio. Kommentoi niitä.

# %% [markdown]
# ### Duraatio

# %% [markdown]
# Laske seuraavaksi kuponkilainan ja nollakuponkilainan Macaulayn duraatio.
#
# Kuponkilaina:
# * Kopioi kuponkilainan kassavirrat ja tunnusluvut omalle välilehdelleen.
# * Lisää kassavirralla painotetut juoksuajat.
# * Lisää edellä laskettujen arvojen nykyarvot.
# * Lisää Tunnusluvut-välilehdelle kuponkilainan Macaulayn duraatio ja selitä sen tulkinta.
#
# Nollakuponkilaina:
# * Kopioi nollakuponkilainan kassavirrat ja tunnusluvut omalle välilehdelleen.
# * Lisää kassavirralla painotetut juoksuajat.
# * Lisää edellä laskettujen arvojen nykyarvot.
# * Lisää Tunnusluvut-välilehdelle nollakuponkilainan Macaulayn duraatio ja selitä sen tulkinta. Vertaa tätä myös juoksuaikaan ja selitä yhteys.

# %% [markdown]
# ### Basis Point Value ja modifioitu duraatio

# %% [markdown]
# Lasketaan seuraavaksi modifioitu duraatio.
#
# Modifioitu duraatio:
# * Laske Tunnusluvut-välilehdelle lainojen modifioitu duraatio ja tulkitse korkosijoitusten korkoriskiä.
# * Laske Tunnusluvut-välilehdelle lainojen Basis Point Value ja tulkitse, mitä arvot tarkoittavat.

# %%
import datetime
import pytz

tz = pytz.timezone('Europe/Helsinki')
print(f'Last modified {tz.localize(datetime.datetime.now()):%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2026-01-13 19:52 by Juha Nurmonen
