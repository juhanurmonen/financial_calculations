# %% [markdown]
# # Rahoituslaskennan menetelmiä

# %% [markdown]
# ## Tehtävä 7: Johdannaisten perusteet ja optioiden hinnoittelu

# %% [markdown]
# ### Oppimistavoitteet

# %% [markdown]
# Tässä tehtävässä tutustutaan johdannaisten perusteisiin, osto- ja myyntioptioon sekä arvonmäärityksen perusteisiin. Lisäksi opiskellaan optioiden hinnoittelua binomihilan ja Black-Scholes-Merton-mallin avulla.

# %% [markdown]
# Tee Excel-tiedostosta helppolukuinen ja hyvien tapojen mukainen. Kirjoita lisäksi jokaiseen osaan lyhyet ja ytimekkäät ohjeet käyttäjille, jotka haluavat soveltaa tekemääsi laskentapohjaa. Lisää samaan tiedostoon (esim. luontevasti laskentapohjasi viereen) lyhyet ja ytimekkäät ohjeet jatkokehittäjille, jotka ehkä haluavat kehittää ja parantaa laskentapohjaasi.

# %% [markdown]
# ### Tausta

# %% [markdown]
# Olet sijoitusneuvojana pienasiakasyrityksessä. Asiakkaasi - tervejärkinen pariskunta, jolta on kuitenkin niin tilaston kuin myös rahoituksen perusteet jääneet aikoinaan opiskelematta - haluaa sinun selvittävän vielä lisää rahoitusmarkkinoita.

# %% [markdown]
# ### Optioista

# %% [markdown]
# Laske osto- ja myyntioption arvot niiden päättymispäivinä ja kuvaa niiden käyttäytymistä.
#
# Markkinoilla on osake ja siihen kohdistuva osto-optio, joka oikeuttaa ostamaan 300 kpl osakkeita A hintaan 29 €.
# * Laske option arvot, jos osakkeen arvo päätöspäivänä on 28 €, 33 € ja 38 €.
# * Kuvaile ja selitä option hinnalle tapahtuvia muutoksia.
#
# * Laske vastaavasti option arvot sopiville osakkeen hinnoille, esim. 20-50 €.
# * Piirrä kuvaaja, joka kuvaa riippuvuutta.
# * Vaihtele option toteutushintaa ja osakkeiden lukumäärää. Kommentoi muutoksia kuvaajassa.
#
# Markkinoilla on myös osake B ja siihen kohdistuva myyntioptio, joka oikeuttaa myymään 250 kpl osakkeita B hintaan 35 euroa.
# * Laske option arvot, jos osakkeen arvo päätöspäivänä on 29 €, 35 € ja 41 €.
# * Kuvaile ja selitä option hinnalle tapahtuvia muutoksia.
#
# * Laske vastaavasti option arvot sopiville osakkeen hinnoille, esim. 20-50 €.
# * Piirrä kuvaaja, joka kuvaa riippuvuutta.
# * Vaihtele option toteutushintaa ja osakkeiden lukumäärää. Kommentoi muutoksia kuvaajassa.

# %% [markdown]
# ### Optiot ja sijoitusstrategiat

# %% [markdown]
# Analysoidaan osto- ja myyntioptioiden käyttäytymistä sekä käytetään niitä eri sijoitusstrategioissa.

# %% [markdown]
# Analysoi myyntioptioiden käyttäytymistä omalla välilehdellään ja osto-optioiden käyttäytymistä omalla välilehdellään. Osakkeen hinta tarkastelutilanteessa on 35 euroa.
# * Optio P1: Myyntioptio, joka oikeuttaa myymään 50 kpl osakkeita A hinnalla 40 €;
# * Optio P2: Myyntioptio, joka oikeuttaa myymään 30 kpl osakkeita A hinnalla 35 €;
# * Optio C1: osto-optio, joka oikeuttaa ostamaan 40 kpl osakkeita A hinnalla 42 €;
# * Optio C2: Osto-optio, joka oikeuttaa ostamaan 35 kpl osakkeita A hinnalla 32 €.

# %% [markdown]
# Optioiden tämänhetkiset hinnat markkinoilla ovat:
# * P1: 31 €;
# * P2: 28 €;
# * C1: 34 €;
# * C2: 37 €.

# %% [markdown]
# Lasketaan seuraavaksi sijoitusten tuottoja.
#
# * Valitse viisi eri muutosskenaariota (eli osakkeen hinnan muutosprosenttia), positiivisia ja negatiivisia.
# * Laske vastaavat osakkeen hinnat sekä optioiden hinnat ja tuotot (euroa ja prosenttia) tuolla osakkeen hinnalla. Kumpi optio tuottaa paremmin kussakin tapauksessa?

# %% [markdown]
# Tutki ja analysoi optiostrategiaa:
# * Laske osakkeen ja option arvot sekä optioiden tuotot (euroina ja prosentteina) soveltuvin prosenttiyksiköiden välein sen mukaan, kuinka monta prosenttia osakkeen arvo on muuttunut.
# * Piirrä kuvaaja, josta voi vertailla optioiden tuottoprosentteja. Milloin ja miksi toisesta optiosta tulee parempi vaihtoehto (tarkka osakkeen arvon muutosprosenttipiste)?

# %% [markdown]
# ### Joukkovelkakirjat ja johdannaiset

# %% [markdown]
# Opetellaan hinnoittelemaan joukkovelkakirjoja ja niiden johdannaisia.

# %% [markdown]
# Markkinoilla on osake JVK A nimellisarvoltaan 8 000 €, kuponki 580 € ja aikaa jäljellä seitsemän vuotta (juoksuaika maturiteetti).
# * Laske JVK:n hinta, kun markkinoiden maturiteettituotto on 8 %.
# * Laske JVK:n hinnat myös, kun maturiteettituotto on 4 %, 10 % ja 18 %.
# * Kommentoi, miten JVK:n hinta muuttuu.

# %% [markdown]
# Vertaile JVK:n hintaa maturiteettituoton muuttuessa.
# * Tee vastaavat laskelmat, kun maturiteettituotto muuttuu tilanteeseen sopivien prosenttiyksiköiden (tai niiden osien) välein.
# * Piirrä JVK:n hinnasta kuvaaja maturiteettituoton muuttuessa.
# * Kommentoi JVK:n hinnan muutosta maturiteettituoton muuttuessa.
# * Miten JVK:n hinta muuttuu, jos lähtöarvot (JVK:n nimellisarvo, kuponki ja juoksuaika) muuttuvat?

# %% [markdown]
# Markkinoilla on tuohon JVK:hon kohdistuvat optiot, joista A oikeuttaa ostamaan 30 kpl joukkovelkakirjoja 7 000 euron hintaan.
# * Laske ensin option arvo maturiteettituotolla 8 %.
# * Laske sitten option arvo vastaavasti muilla maturiteettituotoilla 4 %, 10 % ja 18 %.
# * Kommentoi, miten option arvo muuttuu.
# * Kommentoi, miten joukkovelkakirjan hinta vaikuttaa option hintaan.
# * Kommentoi, miten maturiteettituotto vaikuttaa option hintaan.

# %% [markdown]
# Vertaile option arvoa maturiteettituoton muuttuessa.
# * Tee vastaavat laskelmat, kun maturiteettituotto muuttuu tilanteeseen sopivien prosenttiyksiköiden (tai niiden osien) välein.
# * Piirrä option arvosta kuvaaja JVK:n hinnan muuttuessa.
# * Kommentoi option arvon muutosta JVK:n hinnan muuttuessa.
# * Piirrä myös kuvaaja option arvosta maturiteettituoton muuttuessa ja kommentoi sitä.
# * Miten JVK:n hinta muuttuu, jos lähtöarvot muuttuvat?

# %% [markdown]
# Markkinoilla on myös tuohon JVK:hon kohdistuva toinen optio B, joka oikeuttaa myymään 40 kpl joukkovelkakirjoja 10 000 euron hintaan.
# * Laske ensin option arvo maturiteettituotolla 8 %.
# * Laske sitten option arvo vastaavasti muilla maturiteettituotoilla 4 %, 10 % ja 18 %.
# * Kommentoi, miten option arvo muuttuu.
# * Kommentoi, miten joukkovelkakirjan hinta vaikuttaa option hintaan.
# * Kommentoi, miten maturiteettituotto vaikuttaa option hintaan.

# %% [markdown]
# Vertaile option arvoa maturiteettituoton muuttuessa.
# * Tee vastaavat laskelmat, kun maturiteettituotto muuttuu tilanteeseen sopivien prosenttiyksiköiden (tai niiden osien) välein.
# * Piirrä option arvosta kuvaaja JVK:n hinnan muuttuessa.
# * Kommentoi option arvon muutosta JVK:n hinnan muuttuessa.
# * Piirrä myös kuvaaja option arvosta maturiteettituoton muuttuessa ja kommentoi sitä.
# * Miten JVK:n hinta muuttuu, jos lähtöarvot muuttuvat?

# %% [markdown]
# ### Binomihila

# %% [markdown]
# Käy läpi hilalaskennan vaiheet: hintaprosessi, todennäköisyydet, payoffit, todennäköisyyspainotetut payoffit ja payoffin odotusarvon diskonttaus.
#
# Hinnoittele näiden avulla 0, 1, 2, 3 ja 4-vuotinen osto-optio.
#
# Historiatietojen perusteella arvellaan, että hinnannousu olisi 25 prosenttia ja hinnanlasku 10 prosenttia. Riskitön korkotuotto arvioidaan 3,5 %:n suuruiseksi. Option toteutushinta on 300,00 €.
#
# Mitä tapahtuu, jos lisätään volatiliteettia? Entä mitä tapahtuu silloin optiohinnalle? Entä jos muutetaan toteutushintaa tai korkotasoa? Tee erilaisia näihin kysmyksiin liittyviä tarkasteluja ja anna niihin perustellut vastaukset.

# %% [markdown]
# ### Option hinnan laskeminen

# %% [markdown]
# Markkinoilla on osake, jonka hinta on 15 euroa ja volatiliteetti 40 %. Osakkeeseen kohdistuu optio, joka oikeuttaa ostamaan yhden osakkeen 3 v 4 kk päästä 10 euron hintaan. Riskitön korkotaso arvellaan 2,752 %:ksi.
#
# Laske B-S-M-kaavan arvot d1, d2, N(d1), N(d2) ja exp(-rt).
# * Mikä on osto-option hinta C?
#
# *Entä jos optio onkin myyntioptio?*
#
# Laske vielä B-S-M-kaavan arvot N(-d1), N(-d2).
# * Mikä on myyntioption hinta P?

# %% [markdown]
# ### Osakkeen hinnan vaikutus option hintaan

# %% [markdown]
# Jatketaan edellistä tehtävää.
#
# * Laske osto-option hinta C osakkeen hinnan eri arvoilla.
# * Laske myyntioption hinta P osakkeen hinnan eri arvoilla.
#
# Piirrä lopuksi kuva, jossa vaaka-akselilla on osakkeen hinta S ja pystyakselilla osto-option hinta C sekä myyntioption hinta P.
#
# Mitä voit laskelmiesi ja kuvan perusteella sanoa kyseisistä optioista?

# %%
import datetime
import pytz

tz = pytz.timezone('Europe/Helsinki')
print(f'Last modified {tz.localize(datetime.datetime.now()):%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2026-01-13 22:10 by Juha Nurmonen
