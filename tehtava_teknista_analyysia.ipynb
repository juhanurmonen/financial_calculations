# %% [markdown]
# # Rahoituslaskennan menetelmiä

# %% [markdown]
# ## Tehtävä 8B: Teknistä analyysia

# %% [markdown]
# ### Oppimistavoitteet

# %% [markdown]
# Tässä tehtävässä tutustutaan osakekurssien tekniseen analyysiin historiallisten arvojen avulla.

# %% [markdown]
# Tee Excel-tiedostosta helppolukuinen ja hyvien tapojen mukainen. Kirjoita lisäksi jokaiseen osaan lyhyet ja ytimekkäät ohjeet käyttäjille, jotka haluavat soveltaa tekemääsi laskentapohjaa. Lisää samaan tiedostoon (esim. luontevasti laskentapohjasi viereen) lyhyet ja ytimekkäät ohjeet jatkokehittäjille, jotka ehkä haluavat kehittää ja parantaa laskentapohjaasi.

# %% [markdown]
# ### Tausta

# %% [markdown]
# Olet sijoitusneuvojana pienasiakasyrityksessä. Asiakkaasi - tervejärkinen pariskunta, jolta on kuitenkin niin tilaston kuin myös rahoituksen perusteet jääneet aikoinaan opiskelematta - haluaa sinun selvittävän vielä lisää rahoitusmarkkinoita.

# %% [markdown]
# Valitse asiakkaasi haluamasi yritys hae sen osakkeiden päivittäiset päätöskurssit vähintään viimeisen kokonaisen kuukauden ajalta. Halutessaan voi käyttää samaa aineistoa kuin tehtävässä 8A.

# %% [markdown]
# ### Hinnoittelumallin ja historiallisen volatiliteetin soveltaminen

# %% [markdown]
# Ota tarkasteluun valisemasi osakkeen maaliskuun 2026 kurssitiedot. Tee hinnoittelumallin ja historiallisen volatiliteetin avulla arvioita huhtikuun päätöskurssien arvoista. Mitä voit niistä sanoa?

# %% [markdown]
# ### Bollingerin nauhat

# %% [markdown]
# Ota tarkasteluun valitsemasi yrityksen maaliskuun 2026 kurssitiedot. Tee Bollingerin nauhojen avulla arvioita huhtikuun päätöskurssien arvoista. Mitä voit niistä sanoa?

# %% [markdown]
# ### Fibonaccin tasot

# %% [markdown]
# Tarkastele valitsemasi yrityksen maaliskuun 2026 kurssitietoja. Selvitä ensin maaliskuun päätöskurssien suurin ja pienin arvo. Laske näihin nojautuen
# * Fibonaccin 23,6 %:n Fibonaccin ns. retracement level
# * Fibonaccin 61,8 %:n ns. extension level.

# %%
import datetime
import pytz

tz = pytz.timezone('Europe/Helsinki')
print(f'Last modified {tz.localize(datetime.datetime.now()):%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2026-04-14 15:08 by Juha Nurmonen
