# %% [markdown]
# # Rahoituslaskennan menetelmiä

# %% [markdown]
# ## Tehtävä 3: Tuoton odotusarvo ja riski

# %% [markdown]
# ### Oppimistavoitteet

# %% [markdown]
# Tässä tehtävässä kerrataan arvopaperin ja salkun tuoton odotusarvon ja riskin laskemista. Lisäksi tehtävässä tehdään erilaisia niihin liittyviä laskelmia. Samalla harjoitellaan myös esittämään asiat selkeästi sekä dokumentoimaan ja selittämään Excelillä tehtyjä laskentapohjia.

# %% [markdown]
# Tee kukin osa omaan välilehteensä.
#
# Tee Excel-tiedostosta helppolukuinen ja hyvien tapojen mukainen. Kirjoita lisäksi jokaiseen osaan lyhyet ja ytimekkäät ohjeet käyttäjille, jotka haluavat soveltaa tekemääsi laskentapohjaa. Lisää samaan tiedostoon (esim. luontevasti laskentapohjasi viereen) lyhyet ja ytimekkäät ohjeet jatkokehittäjille, jotka ehkä haluavat kehittää ja parantaa laskentapohjaasi.

# %% [markdown]
# ## Osa 1

# %% [markdown]
# Tutkimuslaitosten mukaan lähitulevaisuudessa on kolme todennäköistä tilaa taulukon todennäköisyyksillä. Samoin osakkeen tuotto-odotukset näillä näkymillä opn listattu taulukkoon. Laske tämän osakkeen tuotto-odotus ja keskihajonta. Miten tuotto-odotus ja volatiliteetti muuttuvat eri arvoilla? Tulkitse laskelmiasi myös sanallisesti.
#
# <table>
#
# <tr><th>Tulevaisuudentila</th><th>Laskukausi</th><th>Normaali</th><th>Nousukausi</th></tr>
#
# <tr align="center"><td>Todennäköisyys</td><td>27 %</td><td>46 %</td><td>27 %</td></tr>
#
# <tr align="center"><td>Tuotto-odotus</td><td>33,5 %</td><td>11 %</td><td>-5 %</td></tr>
#
# </table>

# %% [markdown]
# ## Osa 2

# %% [markdown]
# Tee kahden osakkeen portfolion laskentapohja, jossa tarkoitus on laskea portfolion odotettu tuotto ja volatiliteetti. Tee ensin tietomalli, jossa on seuraavat arvot.
#
# <table>
#
# <tr><th>Portfolio</th><th>Osake A</th><th>Osake B</th></tr>
#
# <tr align="center"><td>Tuotto-odotus</td><td>18 %</td><td>33 %</td></tr>
#
# <tr align="center"><td>Keskihajonta</td><td>45 %</td><td>65 %</td></tr>
#
# <tr align="center"><td>Paino</td><td>50 %</td><td>50 %</td></tr>
#
# <tr align="center"><td>Korrelaatio</td><td colspan="2">0,24</td></tr>
#
# </table>

# %% [markdown]
# Tee sitten herkkyysanalyysi, jossa vaihtelet korrelaation arvoja. Tyypillisesti korrelaatiot ovat välillä 0,3–0,6, mutta näidenkin ulkopuolelle voi mennä.
#
# Tee myös (ainakin) toinen herkkyysanalyysi, jossa lasket portfolion tuotto-odotuksia ja volatiliteetteja osakkeiden A ja B eri painoilla salkussa.
#
# Muitakin herkkyysanalyyseja ja skenaarioita voi tehdä.

# %% [markdown]
# ## Osa 3

# %% [markdown]
# Katsotaan seuraavien osakkeiden tunnuslukuja.
#
# <table>
#
# <tr><th>Tulevaisuudentila</th><th colspan="5">Tuotto-odotus</th></tr>
#
# <tr><td>todennäköisyys</td><td>Osake A</td><td>Osake B</td><td>Osake C</td><td>Osake D</td><td>Osake E</td></tr>
#
# <tr><td>Taantuma 25 %</td><td>12,38 %</td><td>25,72 %</td><td>26,33 %</td><td>9,51 %</td><td>41,50 %</td></tr>
#
# <tr><td>Normaali 40 %</td><td>32,26 %</td><td>13,15 %</td><td>8,32 %</td><td>27,16 %</td><td>32,92 %</td></tr>
#
# <tr><td>Nousukausi 35 %</td><td>53,26 %</td><td>17,38 %</td><td>5,83 %</td><td>42,26 %</td><td>12,32 %</td></tr>
#
# </table>
#
# Laske osakkeiden tuotto-odotukset ja volatiliteetit. Kommentoi ja analysoi laskelmiesi tuloksia monipuolisesti.

# %% [markdown]
# ## Osa 4

# %% [markdown]
# Jatketaan tehtävää osasta 3. Lasketaan seuraavaksi osakkeista A–E koostuvan salkun tuotto ja riski olettaen tulevaisuudennäkymien säilyvän samanlaisena. Ota siis edeltä osasta 3 osakkeiden tuotto-odotukset tulevaisuudentila-riviltä normaali ja lisää alla olevien taulukoiden tiedot laskentapohjasi tueksi.
#
# <table>
#
# <tr><th></th><th colspan="5">Osake</th></tr>
#
# <tr><td></td><td>Osake A</td><td>Osake B</td><td>Osake C</td><td>Osake D</td><td>Osake E</td></tr>
#
# <tr><td>Keskihajonta</td><td>45,12 %</td><td>33,82 %</td><td>24,15 %</td><td>29,63 %</td><td>35,43 %</td></tr>
#
# <tr><td>Paino</td><td>19,06 %</td><td>22,38 %</td><td>17,57 %</td><td>30,26 %</td><td>10,73 %</td></tr>
#
# </table>

# %% [markdown]
# Korrelaatiot näiden välillä ovat:
#
# <table>
#
# <tr><th>Korrelaatio</th><td>Osake A</td><td>Osake B</td><td>Osake C</td><td>Osake D</td><td>Osake E</td></tr>
#
# <tr><td>Osake A</td><td>1,00</td><td>0,22</td><td>0,37</td><td>0,59</td><td>0,49</td></tr>
#
# <tr><td>Osake B</td><td>0,22</td><td>1,00</td><td>0,65</td><td>0,22</td><td>0,34</td></tr>
#
# <tr><td>Osake C</td><td>0,37</td><td>0,65</td><td>1,00</td><td>0,43</td><td>0,16</td></tr>
#
# <tr><td>Osake D</td><td>0,59</td><td>0,22</td><td>0,43</td><td>1,00</td><td>0,57</td></tr>
#
# <tr><td>Osake E</td><td>0,49</td><td>0,34</td><td>0,16</td><td>0,57</td><td>1,00</td></tr>
#
#
# </table>

# %%
import datetime
import pytz

tz = pytz.timezone('Europe/Helsinki')
print(f'Last modified {tz.localize(datetime.datetime.now()):%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2026-01-12 19:51 by Juha Nurmonen
