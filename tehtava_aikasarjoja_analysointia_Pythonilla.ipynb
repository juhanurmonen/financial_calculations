# %% [markdown]
# # Rahoituslaskennan menetelmiä

# %% [markdown]
# ## Tehtävä 8A: Osakekurssien aikasarjojen analysointia Pythonilla

# %% [markdown]
# ### Oppimistavoitteet

# %% [markdown]
# Tässä tehtävässä tutustutaan Python-ohjelmointiin osakkeiden aikasarjojen esittämisessä ja analysoinnissa.

# %% [markdown]
# Tee muistiosta hyvin kommentoitu, helppolukuinen ja hyvien tapojen mukainen. Lisää siis käytännön tulkintoja laskelmiesi yhteyteen. Tulkintojen tulisi olla sellaisia, jotka voi lukea sellaisenaan asiakaspalvelutilanteessa asiakkaalle, jonka ei voi olettaa tuntevan rahoituksen, arvopaperimarkkinoiden tai tilastollisten termien erityissanastoa.
#
# Lisäksi jokaiseen osaan lyhyet ja ytimekkäät ohjeet käyttäjille, jotka haluavat soveltaa tekemääsi laskentapohjaa. Lisää samaan tiedostoon (esim. luontevasti laskentapohjasi viereen) lyhyet ja ytimekkäät ohjeet jatkokehittäjille, jotka ehkä haluavat kehittää ja parantaa laskentapohjaasi.

# %% [markdown]
# ### Tausta

# %% [markdown]
# Olet sijoitusneuvojana pienasiakasyrityksessä. Asiakkaasi - tervejärkinen pariskunta, jolta on kuitenkin niin tilaston kuin myös rahoituksen perusteet jääneet aikoinaan opiskelematta - haluaa sinun selvittävän vielä lisää rahoitusmarkkinoita.

# %% [markdown]
# ### Aikasarjat ja analysointi Pythonilla

# %% [markdown]
# Valitse haluamasi mielenkiintoinen osakekurssi ja siihen liittyvä markkinaindeksi. Tarkoitus on käsitellä osakkeen ja indeksin päivittäisiä päätöskursseja vähintään viimeisen kahden vuoden ajalta.
#
# Käsiteltävän datan tulee olla julkisesti netistä julkisista palveluista saatavilla.

# %% [markdown]
# Analysoi monipuolisesti ja monelta kantilta osakkeen päätöskurssidataa viime vuosilta. Lisäksi päätöskurssien kehitystä on syytä vertailla markkinaindeksin kehityksen kanssa. Käytä tunnuslukuja ja graafista esitysmuotoa. Laskelmat ja kuviot tehdään Pythonilla.

# %% [markdown]
# Tee ainakin seuraavat:
# * Laske osakkeen ja markkinaindeksin keskeisimmät tunnusluvut. Kommentoi tuloksia.
# * Piirrä osakkeen ja indeksin päätöskurssidatasta viivakuvio. Tässä yhteydessä on hyvä ottaa esiin aikasarjan kehitys eri aikajänteillä, esim. 5v, 3v ja 1v.
# * Piirrä edellisen lisäksi samaan kuvioon ainakin 50 ja 200 päivän liukuva keskiarvo. Muitakin vastaavia laskelmia voi tehdä. Onko kuviossasi näkyvissä kuoleman tai kultaista ristiä? Mitä piirtämäsi kuvio kertoo kurssikehityksestä?
# * Laske osakkeen ja markkinaindeksin päiväkurssien päivittäiset muutosprosentit. Piirrä viimeaikaiset muutokset pylväskuviona.

# %% [markdown]
# Jos innostuit, voit tehdä lisäksi osan tai kaikki seuraavista:
# * Tarkastele markkinaindeksin ja osakkeen lineaarista riippuvuutta muodostamalla niiden hajontakuvio.
# * Tarkastele osakkeen ja markkinaindeksin normaalijakautuneisuutta muodostamalla niiden q-q-plot-kuvio.
# * Tee myös markkinaindeksin ja osakkeen korrelaatiomatriisi. Mitä voit sanoa niiden korrelaatiosta ja mitä se tarkoittaa?
# * Piirrä vielä osakkeen ja markkinaindeksin liukuva korrelaatio ja liukuva volatiliteetti.

# %% [markdown]
# Tee edellisen kohdan asiat muistioon (notebook) ohjelmoiden ne Pythonilla.

# %% [markdown]
# Tämä osio palautetaan Moodlen palautuslaatikkoon julkisena linkkinä Googlen Colab -palveluun. Muista linkkiä luodessa käyttää valintaa "Anyone with the link".

# %%
import datetime
import pytz

tz = pytz.timezone('Europe/Helsinki')
print(f'Last modified {tz.localize(datetime.datetime.now()):%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2026-04-14 14:58 by Juha Nurmonen
