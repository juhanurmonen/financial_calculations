# %% [markdown]
# # Rahoituslaskennan menetelmiä

# %% [markdown]
# ## Tehtävä 5: Salkun tuotto- ja riskiluvut

# %% [markdown]
# ### Oppimistavoitteet

# %% [markdown]
# Tässä tehtävässä tutustutaan riskin mittareihin sekä niiden laskemiseen. Samalla opitaan menetelminä todennäköisyysjakaumiin sekä lineaariseen regressioon ja sen hallintaan sekä tulkintaan. Samalla harjoitellaan myös esittämään asiat selkeästi sekä dokumentoimaan ja selittämään Excelillä tehtyjä laskentapohjia ja myös rahoituksen laskelmia.

# %% [markdown]
# Tee Excel-tiedostosta helppolukuinen ja hyvien tapojen mukainen. Kirjoita lisäksi jokaiseen osaan asianmukaiset ohjeet käyttäjille, jotka haluavat soveltaa tekemääsi laskentapohjaa. Lisää samaan tiedostoon (esim. luontevasti laskentapohjasi viereen) lyhyet ja ytimekkäät ohjeet jatkokehittäjille, jotka ehkä haluavat kehittää ja parantaa laskentapohjaasi.

# %% [markdown]
# ## Tausta

# %% [markdown]
# Olet sijoitusneuvojana pienasiakasosastolla. Asiakkaasi — virkeä ja tervejärkinen pariskunta, jolta on kuitenkin niin tilaston kuin myös rahoituksen perusteet jääneet aikoinaan käymättä — haluaa sinun selvittävän rahoitusmarkkinoita ja niihin liittyviä riskejä heidän salkkunsa tietojen (kts. Excel-tiedosto) avulla.

# %% [markdown]
# Hae YIT Oyj:n kurssihistoria ajalta 1.1.2025&dash;28.2.2026. Oletamme yksinkertaisuuden vuoksi, että asiakkaasi salkun arvo on seurannut täsmälleen YIT Oyj:n kurssihistoriaa. Hae myös indeksi OMX Helsinki 25 ajalta 22.6.2025&ndash;28.2.2026 ja käytä sitä markkinaportfoliona.

# %% [markdown]
# Tehtävässä voi käyttää apuna seuraa [Excel-tiedostoa](https://haagahelia-my.sharepoint.com/:x:/g/personal/nurju_haaga-helia_fi/IQCFlLlYZWeHSY9pBti-tVgyAfXs2pFVIZ9Ny_Iq1l2fddA?e=NDcWq1).

# %% [markdown]
# ## Osa 1: Tuotot

# %% [markdown]
# Tee siis ensinnäkin tarvittavat laskelmat tuottolukujen laskemiseen. Tee ne hyvien tapojen mukaisesti niin, että laskelmat (esim. päivätuotot) ovat omalla välilehdellään ja tunnusluvut omallaan. Toisin sanoen:
#
# * Laske salkun päivätuotot Laskelmat-välilehdelle.
# * Laske Tunnusluvut-välilehdelle salkun suurin ja pienin päivätuotto.
# * Laske indeksin päivätuotot Laskelmat-välilehdelle.
# * Laske Tunnusluvut-välilehdelle indeksin suurin ja pienin päivätuotto.
#
# Lisäksi:
# * Laske Tunnusluvut-välilehdelle salkun tuotot.
# * Laske Tunnusluvut-välilehdelle indeksin tuotot.
# * Laske vielä niiden tuottoerot.

# %% [markdown]
# ## Osa 2: Volatiliteetti

# %% [markdown]
# Voit käyttää tässä osiossa valintasi mukaan lineaarisia tai logaritmisia tuottoja.
#
# * Laske Tunnusluvut-välilehdelle salkun vuoden päivätuottojen keskihajonta sekä indeksin vuoden päivätuottojen keskihajonta.
# * Laske Tunnusluvut-välilehdelle salkun ja indeksin vuoden volatiliteetti skaalaamalla asianmukaisella luvulla.
# * Laske Tunnusluvut-välilehdelle vielä salkun ja indeksin Sharpen luvut.

# %% [markdown]
# ## Osa 3: Hajontakuvio, regressiosuora ja beta-kerroin

# %% [markdown]
# Piirrä salkun ja indeksin päivätuotoista hajontakuvio. (Sijoitathan arvot oikeille akseleille!)
#
# * Lisää kuvioon trendline, sen yhtälö sekä selityskerroin.
# * Miten tulkitset kaikkia näitä laskemiasi tietoja?

# %% [markdown]
# Piirrä myös alkuperäisistä luvuista (salkun arvo ja markkinaindeksin arvo) muodostettu viivakuvio – siinä kannattanee käyttää apuna useampaa arvoakselia.

# %% [markdown]
# ## Osa 4: Muut tuotto- ja riskiluvut

# %% [markdown]
# Laske ja lisää myös muut tunnusluvut _selityksineen_, jotka Tunnusluvut–välilehdellä on mainittu.

# %%
import datetime
import pytz

tz = pytz.timezone('Europe/Helsinki')
print(f'Last modified {tz.localize(datetime.datetime.now()):%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2026-03-10 15:43 by Juha Nurmonen
