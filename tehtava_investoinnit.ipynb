# %% [markdown]
# # Rahoituslaskennan menetelmiä

# %% [markdown]
# ## Tehtävä 2: Investoinnit

# %% [markdown]
# ### Oppimistavoitteet

# %% [markdown]
# Tässä tehtävässä tutustutaan investointeihin sekä Excelin perusrahoitusfunktioiden ja entä jos -laskelmien käyttämisestä investointeihin liittyvien rahoituspäätöksiä tehdessä. Samalla opitaan myös esittämään asiat selkeästi sekä dokumentoimaan ja selittämään Excelillä tehtyjä laskentapohjia.

# %% [markdown]
# Tee kukin osa omaan välilehteensä.

# %% [markdown]
# ## Osa 1

# %% [markdown]
# Yritys harkitsee erästä koneen ostamista, jonka hankinnan se aikoo toteuttaa lainarahalla. Investoinnin tiedot ovat seuraavat.
#
# * kone maksaa kertakustannuksena (etukäteen) 400 000 euroa;
# * kustannussäästöjen arvioidaan olevan ensimmäisenä vuonna 25 % investointikustannuksista ja vähenevän seuraavina vuosina 5 % aina edellisestä vuodesta;
# * investoinnin kesto on kymmenen vuotta;
#
# Perustele näiden tietojen ja laskelmiesi avulla
#
# * Kannattaako investointi, jos yrityksen tavoitekorkokanta investoinneille on 10 %?
# * Entä jos tavoitekorkokanta on 20 %?
# * Miten tilanne muuttuu, jos investoinnin jäännösarvoksi arvioidaan 30 % hankintahinnasta?

# %% [markdown]
# ## Osa 2

# %% [markdown]
# Tee yrityksen talouspäällikölle herkkyysanalyyseja, josta näkee, miten eri tavoitekorkokannat ja kustannusten säästöprosentit (pessimistisistä optimistisiin eli negatiivisista positiivisiin) vaikuttavat investoinnin nettonykyarvoon. Käytä tässä hyväksesi ehdollista muotoilua.
#
# Tulkitse laskelmiasi monipuolisesti.

# %% [markdown]
# ## Osa 3

# %% [markdown]
# Laske vielä yllä olevan osan laskelman sisäinen korkokanta. Eli laske investoinnin sisäinen korkokanta ja perustele sen avulla, kannattaako investointi. Tutustu ja selvitä vielä perustellen, miten eri lähtöarvot vaikuttavat vaikuttavat sisäiseen korkokantaan.

# %% [markdown]
# ## Osa 4

# %% [markdown]
# Tee yrityksen talouspäällikölle herkkyysanalyyseja, josta näkee, miten eri arvot koneen hinnalle ja kustannusten säästöprosentille (pessimistisistä optimistisiin eli negatiivisista positiivisiin) vaikuttavat investoinnin sisäiseen korkokantaan. Käytä tässä hyväksesi ehdollista muotoilua. Tulkitse laskelmiasi monipuolisesti.

# %% [markdown]
# ## Osa 5

# %% [markdown]
# Tarkastellaan vielä seuraavaa investointia.
#
# * investointi maksaa kertakustannuksena (etukäteen) 400 000 euroa;
# * vuosituottojen arvioidaan olevan vuosittain 120 000 € ja kustannusten 20 000 €;
# * investoinnin kesto on kymmenen vuotta;
# * jäännösarvo investoinnin päätteeksi on 50 000 €.
#
# Tee tästä investoinnista positiivinen ja realistinen skenaario muuttamalla vuotuisia tuottoa ja vuotuisia kustannuksia oman arviosi mukaan realistiseksi ja optimistiseksi.

# %%
import datetime
import pytz

tz = pytz.timezone('Europe/Helsinki')
print(f'Last modified {tz.localize(datetime.datetime.now()):%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2026-01-12 19:34 by Juha Nurmonen
