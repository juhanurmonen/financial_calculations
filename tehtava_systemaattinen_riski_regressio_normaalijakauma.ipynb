# %% [markdown]
# # Rahoituslaskennan menetelmiä

# %% [markdown]
# ## Tehtävä 4: systemaattinen riski, regressio ja normaalijakauma

# %% [markdown]
# ### Oppimistavoitteet

# %% [markdown]
# Tässä tehtävässä jatketaan arvopaperin ja salkun tuoton ja riskin analysointia. Lisäksi tehtävässä tehdään erilaisia niihin liittyviä laskelmia. Samalla harjoitellaan myös esittämään asiat selkeästi sekä dokumentoimaan ja selittämään Excelillä tehtyjä laskentapohjia.

# %% [markdown]
# Tee Excel-tiedostosta helppolukuinen ja hyvien tapojen mukainen. Kirjoita lisäksi jokaiseen osaan lyhyet ja ytimekkäät ohjeet käyttäjille, jotka haluavat soveltaa tekemääsi laskentapohjaa. Lisää samaan tiedostoon (esim. luontevasti laskentapohjasi viereen) lyhyet ja ytimekkäät ohjeet jatkokehittäjille, jotka ehkä haluavat kehittää ja parantaa laskentapohjaasi.

# %% [markdown]
# Tee kukin osa omaan välilehteensä.

# %% [markdown]
# ## Osa 1

# %% [markdown]
# Tutkit osakemarkkinoita ja kiinnostuit osakkeesta, jonka beta on 0,76, riskitön korko on 4,12 % ja markkinaportfolion tuotto-odotus on 28,23 %. Mikä on osakkeen tuotto-odotus CAP-mallin mukaan?
#
# Tee tästä myös herkkyyanalyysi koskien osakkeita eri betan arvoilla. Mitä tulkintoja voit saaduista arvoista tehdä?

# %% [markdown]
# ## Osa 2

# %% [markdown]
# Lasketaan ja tulkitaan beta-kertoimia.
#
# * Laske osakkeen beta-kerroin, kun sen ja markkinoiden korrelaatiokerroin on 0,54, markkinoiden volatiliteetti on 42 % ja osakkeen volatiliteetti 35 %. Miten tulkitset tulostasi?
# * Tee sitten herkkyysanalyysi, jossa tutkit korrelaatiokertoimen vaikutusta beta-kertoimeen. Miten tulkitset näitä laskuja?

# %% [markdown]
# ## Osa 3

# %% [markdown]
# Salkkuun kuuluu alla olevat osakkeet. Markkinoiden tuotto-odotus on 28,23 % ja riskitön korko on 4,12 %. Mitkä ovat näillä tiedoilla salkun odotettu tuottoprosentti ja beta?
#
# <table>
#
# <tr><th>Osake</th><th>Beta</th><th>Paino</th></tr>
#
# <tr align="center"><td>K</td><td>0,86</td><td>15 %</td></tr>
#
# <tr align="center"><td>L</td><td>1,32</td><td>35 %</td></tr>
#
# <tr align="center"><td>M</td><td>0,95</td><td>20 %</td></tr>
#
# <tr align="center"><td>N</td><td>0,5</td><td>30 %</td></tr>
#
# </table>
#
# Tee lisäksi herkkyysanalyysi tai skenaarioita ja tulkitse niitä markkinoiden tuotto-odotuksen ja riskittömän koron eri arvoilla.

# %% [markdown]
# ## Osa 4

# %% [markdown]
# Hae seuraavaksi YIT Oyj:n kurssilista viimeisen vuoden ajalta. Hae myös indeksi OMX Helsinki 25 ja käytä sitä markkinaportfoliona. Analysoi niiden tuottoja ja tuottojen suhdetta laskemalla (suurin piirtein) kaikki mahdollinen järkevä niiden yhteisvaikutuksen liittyvä.
#
# * Laske siis kummankin päivätuotot.
# * Laske tuottojen hajonnat, korrelaatiot ja kovarianssit.
# * Piirrä hajontakuvio ja regressiosuora.
#
# Tulkitse laskujasi ja piirroksiasi monipuolisesti.

# %% [markdown]
# ## Osa 5

# %% [markdown]
# Tässä osiossa tehdään (ainakin) kaksi kuviota hyvien analyysien kera.
#
# Tee yllä olevasta hakemastasi YIT Oyj:n datasta kynttiläkuvio viimeisen kuukauden havainnoista. Mitä voit kuvion perusteella sanoa?
#
# Tee edellä olevasta (osa 4) viimeisen vuoden regressioanalyysin tuottoluvuista q-q plot -kuvio ja tarkastele sen normaalijakautuneisuutta. Mitä voit tämän perusteella sanoa regressiosuoran termeistä?

# %%
import datetime
import pytz

tz = pytz.timezone('Europe/Helsinki')
print(f'Last modified {tz.localize(datetime.datetime.now()):%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2026-01-13 19:21 by Juha Nurmonen
