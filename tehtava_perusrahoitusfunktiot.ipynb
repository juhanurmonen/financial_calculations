# %% [markdown]
# # Rahoituslaskennan menetelmiä

# %% [markdown]
# ## Tehtävä 1: Perusrahoitusfunktioiden kertaus

# %% [markdown]
# ### Oppimistavoitteet

# %% [markdown]
# Tehtävässä tutustutaan Excelin perusrahoitusfunktioihin ja niiden käyttöön rahoituspäätöksiä tehdessä. Näin tehtäessä opitaan myös esittämään asiat selkeästi sekä dokumentoimaan ja selittämään Excelillä tehtyjä laskentapohjia.

# %% [markdown]
# Tee kukin osa omaan välilehteensä.

# %% [markdown]
# ## Osa 1

# %% [markdown]
# Yritys harkitsee toimintansa laajentamista. Investointi aiotaan toteuttaa lainarahalla.
#
# Lähtötiedot ovat seuraavat:
#
# * investointikustannukset ovat 230 000 euroa;
# * laina-aika on seitsemän vuotta;
# * maksuerät maksetaan neljännesvuosittain;
# * laina sidotaan 6kk Euribor-korkoon, jonka arvellaan olevan keskimäärin 0,5 % koko laina-ajan ja lainan marginaali on 4,5 %.
#
# Laske kunkin vuoden osalta lainasta maksettujen lyhennysten ja korkojen osuus sekä annuiteettilainana että tasalyhenteisenä lainana. Kumpi lainatyyppi yrityksen kannattaa näiden tietojen perusteella valita? Miksi?
#
# Tee Excel-tiedostosta helppolukuinen ja hyvien tapojen mukainen. Kirjoita lisäksi tiedostoon lyhyet ja ytimekkäät ohjeet käyttäjille, jotka haluavat soveltaa tekemääsi laskentapohjaa. Lisää samaan tiedostoon (esim. luontevasti laskentapojasi viereen) lyhyet ja ytimekkäät ohjeet jatkokehittäjille, jotka ehkä haluavat kehittää ja parantaa laskentapohjaasi.

# %% [markdown]
# ## Osa 2

# %% [markdown]
# Lisää myös herkkyysanalyysi, joka kuvaa, miten maksuerän suuruus muuttuu, jos korkokanta ja takaisinmaksuaika (vuosina) muuttuvat. Käytä tässä hyväksesi myös ehdollista muotoilua. Minkälaisia arvoja saat nyt lainan hinnaksi?
#
# Lisää mukaan ohjeet myös peruskäyttäjälle sekä kehittäjälle.

# %% [markdown]
# ## Osa 3

# %% [markdown]
# Laske vielä uudelle välilehdelle yllä olevien laskelmien todelliset korot. Eli laske lainan efektiivinen korkokanta, kun
#
# * pankki veloittaa lainaa otettaessa 3,5 % toimitusmaksua mutta kuitenkin vähintään 600 euroa, ja
# * jokaisen maksuerän yhteydessä maksetaan 7,00 € toimitusmaksua.
#
# Lisää jälleen tiedostoon ohjeet selityksineen peruskäyttäjälle ja kehittäjälle näiden käytöstä.

# %%
import datetime
import pytz

tz = pytz.timezone('Europe/Helsinki')
print(f'Last modified {tz.localize(datetime.datetime.now()):%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2026-01-12 19:01 by Juha Nurmonen
